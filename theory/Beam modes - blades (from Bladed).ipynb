# %% [markdown]
# Created: Monday 29 April 2013
#
# For the blades, just use the modal analysis results from Bladed. There is no need to worry about getting the attachment mode mass and stiffness correct, and the blade structures are more complex so harder to model myself.

# %%
# %pylab inline
from mbwind.io import load_modes_from_Bladed
from mbwind.elements.modal import ModalElement
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
modes = load_modes_from_Bladed('../examples/OC3_Hywind_tower_only.prj')
el = ModalElement('el', modes)

# %% [markdown]
# Check a few mass totals and expected values -- the mass doesn't quite match?

# %%
int(modes.mass), 17738
# Out:
# (17714, 17738)

# %%
int(modes.I0[0]), 363629
# Out:
# (363219, 363629)

# %%
int(modes.J0[0, 0]), 11769090
# Out:
# (11753575, 11769090)

# %% [markdown]
# Mode shapes:

# %%
fig, ax = subplots(3, sharex=True); ax[0].set_xlim(0, modes.x[-1])
ax[0].plot(modes.x, modes.shapes[:, 0, :]); ax[0].set_ylim(-0.03, 0.03)
ax[1].plot(modes.x, modes.shapes[:, 1, :]); ax[1].set_ylim(-1, 1)
ax[2].plot(modes.x, modes.shapes[:, 2, :]); ax[2].set_ylim(-1, 1)
ax[1].legend(['%.2f Hz' % f for f in modes.freqs/2/pi], loc=6,bbox_to_anchor=(1, 0.5));
